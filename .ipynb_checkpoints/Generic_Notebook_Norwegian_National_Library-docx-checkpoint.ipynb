# %% [markdown]
# #### Boot cell
#
# Skip if `module_update.py` is in same folder as notebook, next cell downloads this file which in turn will download other files.

# %%
import urllib.request, shutil
with urllib.request.urlopen("https://raw.githubusercontent.com/Yoonsen/Modules/master/module_update.py") as response, open("module_update.py", 'wb') as out_file:
    shutil.copyfileobj(response, out_file)

# %% [markdown]
# #### Get essentials
#
# Import text and graph modules for analysis, and css for display

# %%
from module_update import update, css
# Out:
# Updated file nbtext.py

# %%
#css()

# %% [markdown]
# # Generisk analyse

# %% [markdown]
# Intro

# %% [markdown]
# ### Start med å importere modulene

# %%
update('graph_networkx_louvain')
import nbtext as nb
import graph_networkx_louvain as gnl
from graph_networkx_louvain import cutdown, make_collocation_graph
# Out:
# Updated file graph_networkx_louvain.py

# %% [markdown]
# ## Bygg korpus og analysér
#
# Hent URN-er fra tekst eller metadata

# %% [markdown]
# ### Fra Word .docx

# %%
korpus = nb.get_urns_from_docx('../Avstandsblikk på norsk litteraturhistorie.docx')

# %% [markdown]
# ### Fra tekstfil .txt

# %%
korpus = nb.get_urns_from_text()

# %% [markdown]
# ### Fra metadata
#
# dewey, emneord, navn , år, etc. Her kan [Webdewey](http://deweysearchno.pansoft.de/webdeweysearch/index.html) være til god hjelp.

# %%
korpus = nb.get_urn({'ddk': '799.2%', 'year':1980, 'next':50, 'limit':300})
len(korpus)
# Out:
# 221

# %% [markdown]
# ## Analyse

# %%
nb.get_urnkonk('kvinner', {'urns':korpus})
# Out:
# <table><tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007011801005?searchText=kvinner' target='_blank' style='text-decoration:none'>Illustrert norsk litteraturhistorie, Elster, Kristian, 1935</a>
#                 </td>
#                 <td>enlls kortelling om cle tre</td>
#                 <td>kvinner</td>
#                 <td style='text-align:left'>i svanenam er et tilskullll</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007011801005?searchText=kvinner' target='_blank' style='text-decoration:none'>Illustrert norsk litteraturhistorie, Elster, Kristian, 1935</a>
#                 </td>
#                 <td>stort- og sterktfølende menn og</td>
#                 <td>kvinner</td>
#                 <td style='text-align:left'>, og handlingen er dramatisk</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007011801005?searchText=kvinner' target='_blank' style='text-decoration:none'>Illustrert norsk litteraturhistorie, Elster, Kristian, 1935</a>
#                 </td>
#                 <td>og uten bekymring, elsket av</td>
#                 <td>kvinner</td>
#                 <td style='text-align:left'>, og det tindrer av</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007011801005?searchText=kvinner' target='_blank' style='text-decoration:none'>Illustrert norsk litteraturhistorie, Elster, Kristian, 1935</a>
#                 </td>
#                 <td>dot er da mange andre</td>
#                 <td>kvinner</td>
#                 <td style='text-align:left'>enn Helga , » Bior</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007011801005?searchText=kvinner' target='_blank' style='text-decoration:none'>Illustrert norsk litteraturhistorie, Elster, Kristian, 1935</a>
#                 </td>
#                 <td>eie . Men med andre</td>
#                 <td>kvinner</td>
#                 <td style='text-align:left'>skal du få din vilje</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007011801004?searchText=kvinner' target='_blank' style='text-decoration:none'>Illustrert norsk litteraturhistorie, Elster, Kristian, 1935</a>
#                 </td>
#                 <td>, de vegelsinnede menn og</td>
#                 <td>kvinner</td>
#                 <td style='text-align:left'>, de adstadige halvsure borgere</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007021501117?searchText=kvinner' target='_blank' style='text-decoration:none'>Illustrert norsk litteraturhistorie, Elster, Kristian, 1935</a>
#                 </td>
#                 <td>førte til ekteskap . De</td>
#                 <td>kvinner</td>
#                 <td style='text-align:left'>han beiler til , er</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007021501117?searchText=kvinner' target='_blank' style='text-decoration:none'>Illustrert norsk litteraturhistorie, Elster, Kristian, 1935</a>
#                 </td>
#                 <td>er fint dannede og kultiverte</td>
#                 <td>kvinner</td>
#                 <td style='text-align:left'>, og de viker alle</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007021501117?searchText=kvinner' target='_blank' style='text-decoration:none'>Illustrert norsk litteraturhistorie, Elster, Kristian, 1935</a>
#                 </td>
#                 <td>i veien . De unA6</td>
#                 <td>kvinner</td>
#                 <td style='text-align:left'>nar ikke kunnet nam inntagende</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007021501117?searchText=kvinner' target='_blank' style='text-decoration:none'>Illustrert norsk litteraturhistorie, Elster, Kristian, 1935</a>
#                 </td>
#                 <td>disse elskovslivuiner er de enkelte</td>
#                 <td>kvinner</td>
#                 <td style='text-align:left'>liort « ^ liare en</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007021501117?searchText=kvinner' target='_blank' style='text-decoration:none'>Illustrert norsk litteraturhistorie, Elster, Kristian, 1935</a>
#                 </td>
#                 <td>kvinners altovokrenlle evne , om</td>
#                 <td>kvinner</td>
#                 <td style='text-align:left'>Bom < lriveß til barnemorll</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007010300018?searchText=kvinner' target='_blank' style='text-decoration:none'>Illustrert norsk litteraturhistorie, Elster, Kristian, 1934</a>
#                 </td>
#                 <td>forfatterskap . Og hans unge</td>
#                 <td>kvinner</td>
#                 <td style='text-align:left'>er nesten alltid religi^st stemte</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007010300018?searchText=kvinner' target='_blank' style='text-decoration:none'>Illustrert norsk litteraturhistorie, Elster, Kristian, 1934</a>
#                 </td>
#                 <td>menn og en streng lor</td>
#                 <td>kvinner</td>
#                 <td style='text-align:left'>; en dobbelt lønnssats ,</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007010300018?searchText=kvinner' target='_blank' style='text-decoration:none'>Illustrert norsk litteraturhistorie, Elster, Kristian, 1934</a>
#                 </td>
#                 <td>menn og en lav kor</td>
#                 <td>kvinner</td>
#                 <td style='text-align:left'>. Hun t > rte</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007010300018?searchText=kvinner' target='_blank' style='text-decoration:none'>Illustrert norsk litteraturhistorie, Elster, Kristian, 1934</a>
#                 </td>
#                 <td>den mannlige hovedperson mellem to</td>
#                 <td>kvinner</td>
#                 <td style='text-align:left'>, den ville og voldsomme</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007010300018?searchText=kvinner' target='_blank' style='text-decoration:none'>Illustrert norsk litteraturhistorie, Elster, Kristian, 1934</a>
#                 </td>
#                 <td>er motsetningsforholdet mellem de to</td>
#                 <td>kvinner</td>
#                 <td style='text-align:left'>, Margit og Signe ,</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007010300045?searchText=kvinner' target='_blank' style='text-decoration:none'>Illustrert norsk litteraturhistorie, Elster, Kristian, 1934</a>
#                 </td>
#                 <td>hykleri , — menn og</td>
#                 <td>kvinner</td>
#                 <td style='text-align:left'>Bom levde sitt eget liv</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007010300045?searchText=kvinner' target='_blank' style='text-decoration:none'>Illustrert norsk litteraturhistorie, Elster, Kristian, 1934</a>
#                 </td>
#                 <td>skjebne med sine romaners ulykkelige</td>
#                 <td>kvinner</td>
#                 <td style='text-align:left'>som lider under sin erotikks</td>
#             </tr>
# <tr>
#                 <td>
